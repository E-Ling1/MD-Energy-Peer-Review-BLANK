# %%
#Run this cell
from IPython.display import Image

# %% [markdown]
# Question 1 Output:

# %% [raw]
# Source  Coal  Petroleum Products  Natural Gas  Total
# 1970     0.1                 4.6          3.9    8.7
# 1971     0.1                 4.6          4.0    8.7
# 1972     0.0                 4.5          4.1    8.6
# 1973     0.0                 4.4          3.9    8.4
# 1974     0.0                 4.2          3.8    8.0
# Source  Coal  Petroleum Products  Natural Gas  Total
# 1970     0.1                 2.2          1.4    3.7
# 1971     0.1                 2.7          1.5    4.3
# 1972     0.1                 2.7          1.6    4.5
# 1973     0.1                 2.8          1.6    4.5
# 1974     0.1                 2.4          1.6    4.1
# Source  Coal  Petroleum Products  Natural Gas  Total
# 1970    14.9                 5.4          2.3   22.6
# 1971    12.8                 7.6          2.5   22.9
# 1972    10.4                 7.5          3.1   21.0
# 1973    14.5                 7.8          3.1   25.5
# 1974    10.9                 6.0          3.0   19.9
# Source  Coal  Petroleum Products  Natural Gas  Total
# 1970     0.0                19.4          0.1   19.5
# 1971     0.0                19.4          0.1   19.5
# 1972     0.0                20.4          0.2   20.6
# 1973     0.0                21.5          0.1   21.7
# 1974     0.0                21.1          0.1   21.2
# Source  Coal  Petroleum Products  Natural Gas  Total
# 1970    13.9                 5.1          0.6   19.6
# 1971    12.6                 6.9          0.5   20.0
# 1972    10.6                10.5          0.4   21.5
# 1973     9.2                12.0          0.5   21.7
# 1974     9.2                13.2          0.7   23.1

# %% [markdown]
# Question 2 Pt.1 Output Example:

# %%
Image("Img/residential_graph.png")

# %% [markdown]
# Pt.2 Output:

# %%
Image("Img/sector_graph.png")

# %% [markdown]
# Pt. 3 Output:

# %% [raw]
# Residential Sector Average Yearly Emissions:
# 7.026 Million Metric Tons
#
# Commercial Sector Average Yearly Emissions:
# 4.246 Million Metric Tons
#
# Industrial Sector Average Yearly Emissions:
# 10.136 Million Metric Tons
#
# Transportation Sector Average Yearly Emissions:
# 26.052 Million Metric Tons
#
# Electricity Sector Average Yearly Emissions:
# 23.396 Million Metric Tons
#
#
# Coal Usage Average Yearly Emissions:
# 23.974 Million Metric Tons
#
# Petroleum Usage Average Yearly Emissions:
# 36.742 Million Metric Tons
#
# Natural Gas Usage Average Yearly Emissions:
# 10.12 Million Metric Tons

# %% [markdown]
# Pt.4 Output:

# %%
Image("Img/total_graph.png")
